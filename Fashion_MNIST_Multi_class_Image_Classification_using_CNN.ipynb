# %%
import numpy as np
from sklearn.metrics import confusion_matrix,classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %%
actual    = np.array(
  ['Dog','Dog','Dog','Not Dog','Dog','Not Dog','Dog','Dog','Not Dog','Not Dog'])
predicted = np.array(
  ['Dog','Not Dog','Dog','Not Dog','Dog','Dog','Dog','Dog','Not Dog','Not Dog'])

# %%
cm = confusion_matrix(actual,predicted)

# %%
sns.heatmap(cm,
            annot=True,
            fmt='g',
            xticklabels=['Dog','Not Dog'],
            yticklabels=['Dog','Not Dog'])
plt.ylabel('Actual', fontsize=13)
plt.title('Confusion Matrix', fontsize=17, pad=20)
plt.gca().xaxis.set_label_position('top')
plt.xlabel('Prediction', fontsize=13)
plt.gca().xaxis.tick_top()

plt.gca().figure.subplots_adjust(bottom=0.2)
plt.gca().figure.text(0.5, 0.05, 'Prediction', ha='center', fontsize=13)
plt.show()

# %%
print(classification_report(actual, predicted))
# Out:
#               precision    recall  f1-score   support
#
#          Dog       0.83      0.83      0.83         6
#      Not Dog       0.75      0.75      0.75         4
#
#     accuracy                           0.80        10
#    macro avg       0.79      0.79      0.79        10
# weighted avg       0.80      0.80      0.80        10

# %% [markdown]
# Implementation of Confusion Matrix for Multi-Class classification using python

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib.pyplot as plt

# %%
y_true = ['Cat'] * 10 + ['Dog'] * 12 + ['Rabit'] * 10
y_pred = ['Cat'] * 8 + ['Dog'] + ['Rabit'] + ['Cat'] * 2 + ['Dog'] * 10 + ['Rabit'] * 8 + ['Dog'] * 2
classes = ['Cat', 'Dog', 'Rabit']

# %%
cm = confusion_matrix(y_true, y_pred, labels=classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix', fontsize=15, pad=20)
plt.xlabel('Prediction', fontsize=11)
plt.ylabel('Actual', fontsize=11)
plt.gca().xaxis.set_label_position('top')
plt.gca().xaxis.tick_top()
plt.gca().figure.subplots_adjust(bottom=0.2)
plt.gca().figure.text(0.5, 0.05, 'Prediction', ha='center', fontsize=13)

plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#          Cat       0.80      0.80      0.80        10
#          Dog       0.77      0.83      0.80        12
#        Rabit       0.89      0.80      0.84        10
#
#     accuracy                           0.81        32
#    macro avg       0.82      0.81      0.81        32
# weighted avg       0.82      0.81      0.81        32

# %% [markdown]
# Multiclass classification using scikit-learn.
# step-by-step implementation of Multiclass Classification along with various classifiers

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=0)

# %% [markdown]
# Decision Tree Classifier:

# %%
from sklearn.tree import DecisionTreeClassifier

dtree = DecisionTreeClassifier(max_depth=2, random_state=0)
dtree.fit(X_train, y_train)
dtree_preds = dtree.predict(X_test)
dtree_acc = accuracy_score(y_test, dtree_preds)
dtree_cm = confusion_matrix(y_test, dtree_preds)

print("Decision Tree Accuracy:", dtree_acc)

plt.figure(figsize=(4, 3))
sns.heatmap(dtree_cm, annot=True, cmap="Blues", fmt="d")
plt.title("Decision Tree Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Decision Tree Accuracy: 0.9111111111111111

# %% [markdown]
# 2. Support Vector Machine(SVM) Classifier:

# %%
from sklearn.svm import SVC

svm = SVC(kernel='linear', C=1, random_state=0)
svm.fit(X_train, y_train)
svm_preds = svm.predict(X_test)
svm_acc = accuracy_score(y_test, svm_preds)
svm_cm = confusion_matrix(y_test, svm_preds)

print("SVM Accuracy:", svm_acc)

plt.figure(figsize=(4, 3))
sns.heatmap(svm_cm, annot=True, cmap="Blues", fmt="d")
plt.title("SVM Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# SVM Accuracy: 0.9777777777777777

# %% [markdown]
# 3. K-Nearest Neighbors(KNN) Classifiers:

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train, y_train)
knn_preds = knn.predict(X_test)
knn_acc = accuracy_score(y_test, knn_preds)
knn_cm = confusion_matrix(y_test, knn_preds)

print("KNN Accuracy:", knn_acc)

plt.figure(figsize=(4, 3))
sns.heatmap(knn_cm, annot=True, cmap="Blues", fmt="d")
plt.title("KNN Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# KNN Accuracy: 0.9777777777777777

# %% [markdown]
#  4. Naive Bayes Classifier:

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()
nb.fit(X_train, y_train)
nb_preds = nb.predict(X_test)
nb_acc = accuracy_score(y_test, nb_preds)
nb_cm = confusion_matrix(y_test, nb_preds)

print("Naive Bayes Accuracy:", nb_acc)

plt.figure(figsize=(4, 3))
sns.heatmap(nb_cm, annot=True, cmap="Blues", fmt="d")
plt.title("Naive Bayes Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Naive Bayes Accuracy: 1.0

# %% [markdown]
# MNIST dataset (Kaggle) and a simple CNN with TensorFlow/Keras, then compute the confusion matrix using scikit-learn.
#
#
# Fashion-MNIST is an excellent choice for a small, clean binary-classification demo

# %% [markdown]
# Fashion-MNIST Dataset (Quick Facts)
#
# Download size: ~30 MB
#
# Images: 70,000 grayscale images
#
# Image size: 28 × 28
#
# Classes (10): T-shirt, Trouser, Pullover, Dress, Coat, Sandal, Shirt, Sneaker, Bag, Ankle boot
#
# We’ll convert it into binary classification.

# %% [markdown]
# Binary Classification Setup
# Example Binary Problem:
#
# Class 0: T-shirt / Top (label 0)
#
# Class 1: Trouser (label 1)

# %% [markdown]
# Load Fashion-MNIST

# %%
import tensorflow as tf
import numpy as np

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

print("Fashion-MNIST loaded successfully!")
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Fashion-MNIST loaded successfully!

# %% [markdown]
# Keep Only Two Classes (Binary)

# %%
# Select T-shirt (0) and Trouser (1)
train_mask = (y_train == 0) | (y_train == 1)
test_mask  = (y_test == 0) | (y_test == 1)

x_train, y_train = x_train[train_mask], y_train[train_mask]
x_test, y_test   = x_test[test_mask], y_test[test_mask]

print("Binary dataset created!")
# Out:
# Binary dataset created!

# %% [markdown]
# Preprocess Data

# %%
# Normalize and reshape
x_train = x_train / 255.0
x_test  = x_test / 255.0

x_train = x_train[..., np.newaxis]
x_test  = x_test[..., np.newaxis]

# %% [markdown]
# Simple CNN Model (Binary)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, 3, activation='relu', input_shape=(28,28,1)),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Train the Model

# %%
model.fit(x_train, y_train, epochs=5, validation_split=0.2)
# Out:
# Epoch 1/5
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9639 - loss: 0.1008 - val_accuracy: 0.9867 - val_loss: 0.0392
# Epoch 2/5
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9930 - loss: 0.0198 - val_accuracy: 0.9921 - val_loss: 0.0283
# Epoch 3/5
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - accuracy: 0.9948 - loss: 0.0148 - val_accuracy: 0.9942 - val_loss: 0.0280
# Epoch 4/5
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9970 - loss: 0.0084 - val_accuracy: 0.9942 - val_loss: 0.0307
# Epoch 5/5
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9987 - loss: 0.0064 - val_accuracy: 0.9933 - val_loss: 0.0319

# %% [markdown]
# Confusion Matrix Implementation

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

y_pred_prob = model.predict(x_test)
y_pred = (y_pred_prob > 0.5).astype(int).ravel()

cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=["T-shirt", "Trouser"]
)

disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix - Fashion MNIST (Binary)")
plt.show()
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step

# %% [markdown]
# Fashion-MNIST: Multi-Class Classification

# %% [markdown]
# Dataset details
#
# Number of classes: 10
#
# Labels:
#
# Label	Class
# 0	T-shirt / Top
# 1	Trouser
# 2	Pullover
# 3	Dress
# 4	Coat
# 5	Sandal
# 6	Shirt
# 7	Sneaker
# 8	Bag
# 9	Ankle boot

# %%
import tensorflow as tf

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
print("Fashion-MNIST loaded!")
# Out:
# Fashion-MNIST loaded!

# %% [markdown]
# Preprocess Data

# %%
x_train = x_train / 255.0
x_test  = x_test / 255.0

x_train = x_train[..., None]
x_test  = x_test[..., None]

# %% [markdown]
# CNN Model for Multi-Class Classification

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, 3, activation='relu', input_shape=(28,28,1)),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(64, 3, activation='relu'),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')  # 10 classes
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Compile & Train

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(x_train, y_train, epochs=5, validation_split=0.2)
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 70s 44ms/step - accuracy: 0.7647 - loss: 0.6539 - val_accuracy: 0.8728 - val_loss: 0.3427
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - accuracy: 0.8844 - loss: 0.3157 - val_accuracy: 0.8947 - val_loss: 0.2957
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 79s 34ms/step - accuracy: 0.9030 - loss: 0.2650 - val_accuracy: 0.9031 - val_loss: 0.2720
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 50s 33ms/step - accuracy: 0.9126 - loss: 0.2315 - val_accuracy: 0.9051 - val_loss: 0.2629
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 51s 34ms/step - accuracy: 0.9243 - loss: 0.2033 - val_accuracy: 0.9119 - val_loss: 0.2576

# %% [markdown]
# Multi-Class Confusion Matrix

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

y_pred = np.argmax(model.predict(x_test), axis=1)

cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=[
        "T-shirt","Trouser","Pullover","Dress","Coat",
        "Sandal","Shirt","Sneaker","Bag","Ankle boot"
    ]
)

disp.plot(xticks_rotation=45, cmap=plt.cm.Blues)
plt.title("Multi-Class Confusion Matrix (Fashion-MNIST)")
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
